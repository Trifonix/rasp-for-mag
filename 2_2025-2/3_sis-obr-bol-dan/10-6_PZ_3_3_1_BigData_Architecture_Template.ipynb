# %% [markdown]
# # Практическое занятие 3.3.1
# ## Проектирование архитектуры Big Data-системы и промышленного пайплайна обработки данных
#
# **Дисциплина:** Системы обработки больших данных
# **Студент:** ____________________
# **Группа:** _____________________
# **Вариант:** ____________________
# **Дата:** _______________________

# %% [markdown]
# ## Цель работы
# Спроектировать концептуальную архитектуру Big Data-системы и промышленный пайплайн обработки данных для выбранной прикладной задачи.

# %%
import pandas as pd
from IPython.display import display, Markdown

# %%
# Выберите номер своего варианта
variant_number = 1

variant_tasks = {
    1: 'Спроектировать архитектуру системы анализа банковских транзакций для выявления подозрительных операций и поддержки антифрод-мониторинга.',
    2: 'Спроектировать архитектуру системы персонализации товарных предложений для крупного маркетплейса на основе истории просмотров, заказов и поисковых запросов.',
    3: 'Спроектировать архитектуру системы анализа логов цифровой образовательной платформы университета для выявления активности студентов и раннего обнаружения риска академической неуспеваемости.',
    4: 'Спроектировать архитектуру системы мониторинга телеметрии промышленного оборудования для выявления аномалий и предупреждения отказов.',
    5: 'Спроектировать архитектуру системы анализа обращений граждан в государственную цифровую приёмную с классификацией тематики и контролем сроков обработки.',
    6: 'Спроектировать архитектуру системы мониторинга маршрутов городского общественного транспорта на основе геоданных и журналов движения.',
    7: 'Спроектировать архитектуру системы анализа заказов и сроков доставки в логистической компании для прогнозирования задержек.',
    8: 'Спроектировать архитектуру системы анализа клиентской активности оператора связи для прогнозирования оттока абонентов.',
    9: 'Спроектировать архитектуру системы анализа медицинских записей и результатов обследований для поддержки принятия решений в клинике.',
    10: 'Спроектировать архитектуру системы анализа поведения пользователей мобильного банковского приложения для выявления сценариев использования и подозрительной активности.',
    11: 'Спроектировать архитектуру системы анализа посещаемости и спроса в сети розничных магазинов на основе данных касс, чеков и складских остатков.',
    12: 'Спроектировать архитектуру системы анализа заявок в службу технической поддержки ИТ-компании с автоматической маршрутизацией обращений.',
    13: 'Спроектировать архитектуру системы анализа публикаций и пользовательской активности в социальной платформе для выявления трендов и аномального поведения.',
    14: 'Спроектировать архитектуру системы мониторинга энергопотребления в жилом или промышленном объекте на основе данных счётчиков и датчиков.',
    15: 'Спроектировать архитектуру системы анализа дорожной обстановки на основе камер, датчиков и сообщений от навигационных сервисов.',
    16: 'Спроектировать архитектуру системы анализа сельскохозяйственных данных для мониторинга состояния полей, погодных факторов и прогнозирования урожайности.',
    17: 'Спроектировать архитектуру системы анализа транзакций и клиентских действий в интернет-магазине для выявления брошенных корзин и настройки маркетинговых кампаний.',
    18: 'Спроектировать архитектуру системы анализа документов и контрактов в крупной организации для поиска, классификации и контроля исполнения.',
    19: 'Спроектировать архитектуру системы мониторинга киберинцидентов на основе сетевых журналов, журналов безопасности и событий аутентификации.',
    20: 'Спроектировать архитектуру системы анализа туристических потоков и загрузки инфраструктуры региона на основе бронирований, транспортных данных и событий посещения.'
}

display(Markdown(f'### Вариант {variant_number}'))
display(Markdown(variant_tasks[variant_number]))

# %% [markdown]
# ## 1. Постановка задачи
# **Формулировка варианта:**
# _Вставьте или уточните текст варианта._
#
# **Краткое описание предметной области:**
# _Опишите предметную область в 1–2 абзацах._
#
# **Основная цель системы:**
# _Сформулируйте, какую проблему должна решать проектируемая система._

# %% [markdown]
# ## 2. Краткие определения
# Кратко раскройте термины: **Big Data, data pipeline, источник данных, хранилище данных, вычислительный слой, аналитический слой, offline-аналитика, online-аналитика, оркестрация, Data Engineer, Data Scientist**.

# %%
task_analysis = pd.DataFrame({
    'Параметр': [
        'Предметная область',
        'Основная цель системы',
        'Поставщики данных',
        'Пользователи результата',
        'Какое решение поддерживает система',
        'Требуемая частота обновления результата',
        'Нужна ли обработка в реальном времени'
    ],
    'Описание': [''] * 7
})
task_analysis

# %% [markdown]
# ## 3. Анализ прикладной задачи
# _Сделайте краткий вывод по заполненной таблице: кто заинтересован в системе, зачем она нужна, в каком режиме должен формироваться результат._

# %%
sources_df = pd.DataFrame({
    '№': range(1, 7),
    'Источник данных': [''] * 6,
    'Тип данных': [''] * 6,
    'Формат': [''] * 6,
    'Частота поступления': [''] * 6,
    'Примерный объём': [''] * 6,
    'Проблемы качества': [''] * 6
})
sources_df

# %% [markdown]
# ## 4. Источники данных
# _Кратко поясните, какие источники являются основными, какие вспомогательными, какие источники наиболее проблемны с точки зрения качества и скорости поступления._

# %%
data_types_df = pd.DataFrame({
    'Категория данных': [
        'Структурированные',
        'Неструктурированные',
        'Полуструктурированные',
        'Потоковые',
        'Архивные',
        'Справочные'
    ],
    'Какие данные относятся к этой категории': [''] * 6,
    'Почему': [''] * 6
})
data_types_df

# %% [markdown]
# ## 5. Классификация данных
# _Сделайте вывод о разнообразии данных в системе и о том, как это влияет на выбор архитектурных решений._

# %%
pipeline_df = pd.DataFrame({
    'Этап': [
        'Получение данных',
        'Загрузка в систему',
        'Очистка данных',
        'Преобразование данных',
        'Интеграция источников',
        'Хранение данных',
        'Агрегация и расчёт признаков',
        'Аналитическая обработка',
        'Формирование результата',
        'Передача результата пользователю/системе'
    ],
    'Что происходит на этапе': [''] * 10,
    'Входные данные': [''] * 10,
    'Результат этапа': [''] * 10
})
pipeline_df

# %% [markdown]
# ## 6. Общий пайплайн обработки данных
# _Опишите полный маршрут движения данных. Укажите, какие этапы являются критическими и почему._

# %%
layers_df = pd.DataFrame({
    'Архитектурный слой': [
        'Источники данных',
        'Интеграция данных',
        'Хранение данных',
        'Вычислительный слой',
        'Аналитический слой',
        'Слой представления',
        'Оркестрация и контроль'
    ],
    'Назначение': [''] * 7,
    'Какие компоненты или классы технологий могут использоваться': [''] * 7
})
layers_df

# %% [markdown]
# ## 7. Архитектурные слои системы
# _Поясните, почему система разбита именно на такие слои, какой слой является наиболее важным и где возможны узкие места._

# %% [markdown]
# ## 8. Архитектурная схема
# Вставьте сюда схему проектируемой системы.
#
# Пример вставки:
# `![Архитектурная схема](architecture_scheme.png)`
#
# _После схемы кратко поясните, как она устроена и как по ней движутся данные._

# %%
modes_df = pd.DataFrame({
    'Процесс': [''] * 6,
    'Режим': [''] * 6,
    'Почему выбран этот режим': [''] * 6
})
modes_df

# %% [markdown]
# ## 9. Offline- и online-контуры
# _Укажите, какие процессы могут выполняться пакетно, а какие требуют оперативной обработки. Обоснуйте необходимость или отсутствие online-компонента._

# %%
orchestration_df = pd.DataFrame({
    'Задача': [
        'Загрузка данных',
        'Очистка данных',
        'Преобразование',
        'Интеграция',
        'Агрегация',
        'Аналитическая обработка',
        'Формирование результата'
    ],
    'От каких задач зависит': ['', 'Загрузка данных', 'Очистка данных', 'Преобразование', 'Интеграция', 'Агрегация', 'Аналитическая обработка'],
    'Тип запуска': [''] * 7,
    'Что делать при ошибке': [''] * 7
})
orchestration_df

# %% [markdown]
# ## 10. Оркестрация и автоматизация
# _Поясните, какие задачи должны запускаться автоматически, какие выполняются по расписанию, какие — по событию, и почему ручной запуск нежелателен._

# %%
roles_df = pd.DataFrame({
    'Роль': ['Data Engineer', 'Data Scientist', 'Пользователь результата / BI-аналитик / эксперт'],
    'Основные функции в проекте': [''] * 3
})
roles_df

# %% [markdown]
# ## 11. Распределение ролей
# _Покажите, какие задачи в проекте относятся к инженерии данных, какие — к аналитике, и кто использует итоговый результат системы._

# %%
risks_df = pd.DataFrame({
    'Риск': [''] * 6,
    'На каком этапе возникает': [''] * 6,
    'Возможные последствия': [''] * 6,
    'Способ снижения риска': [''] * 6
})
risks_df

# %% [markdown]
# ## 12. Риски и ограничения
# _Опишите ключевые риски системы: проблемы качества данных, задержки поступления, ошибки интеграции, изменение схемы источников, проблемы доступа и другие существенные ограничения._

# %%
summary_df = pd.DataFrame({
    'Компонент системы': [''] * 8,
    'Назначение': [''] * 8,
    'Тип данных': [''] * 8,
    'Режим работы': [''] * 8,
    'Ответственная роль': [''] * 8
})
summary_df

# %% [markdown]
# ## 13. Итоговая сводная таблица архитектуры
# _Обобщите систему в виде сводной таблицы: из каких ключевых компонентов она состоит, зачем нужен каждый из них, какие данные он обрабатывает и кто за него отвечает._

# %% [markdown]
# ## 14. Итоговые выводы
# В выводах отразите:
# 1. Какую систему вы спроектировали.
# 2. Какие источники данных являются ключевыми.
# 3. Каков общий маршрут движения данных.
# 4. Какие слои системы наиболее важны.
# 5. Где требуются автоматизация и контроль.
# 6. Какие риски наиболее существенны.
# 7. Что оказалось самым сложным при проектировании.

# %% [markdown]
# ## 15. Контрольные вопросы
# 1. Почему отдельная аналитическая модель не является промышленной системой сама по себе?
# _Ответ._
#
# 2. Что такое data pipeline и какие этапы он обычно включает?
# _Ответ._
#
# 3. Чем offline-аналитика отличается от online-аналитики?
# _Ответ._
#
# 4. Зачем нужна оркестрация задач обработки данных?
# _Ответ._
#
# 5. В чём состоит различие между ролями Data Engineer и Data Scientist?
# _Ответ._

# %% [markdown]
# ## 16. Чек-лист готовности
# - [ ] Указан номер варианта
# - [ ] Описана предметная задача
# - [ ] Заполнена таблица анализа задачи
# - [ ] Заполнена таблица источников данных
# - [ ] Выполнена классификация данных
# - [ ] Спроектирован общий пайплайн
# - [ ] Описаны архитектурные слои
# - [ ] Добавлена архитектурная схема
# - [ ] Выделены offline- и online-контуры
# - [ ] Описана оркестрация
# - [ ] Разграничены роли участников
# - [ ] Выявлены риски
# - [ ] Заполнена итоговая сводная таблица
# - [ ] Сформулированы выводы
# - [ ] Даны ответы на контрольные вопросы
